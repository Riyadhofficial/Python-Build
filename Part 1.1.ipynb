# %%
import pymysql
import pandas as pd
import sys
import datetime
import matplotlib.pyplot as plt

# %%
import mysql.connector

# %%
from sqlalchemy import create_engine

# %%
infy_df=pd.read_csv("/Users/mohammedreyas/Desktop/infy_stock.csv")

# %%
nifty_df=pd.read_csv("/Users/mohammedreyas/Desktop/nifty_it_index.csv")

# %%
plt.plot(infy_df['Close'], label='Close Price history')

# %%
plt.plot(nifty_df['Close'], label='Close Price history')

# %%
engine = create_engine('mysql+mysqlconnector://root:riaz@1706@localhost/riaz')

# %%
engine
# Out:
# Engine(mysql+mysqlconnector://root:***@localhost/riaz)

# %%
infy_df.to_sql(con=engine, name='infy_df', if_exists='replace')

# %%
nifty_df.to_sql(con=engine, name='nifty_df', if_exists='replace')

# %%
# Data has been loaded into  mysql
